# %% [markdown]
# # Fault tree
#
# Report section 3.1. Top event, basic events, and propagation of the probabilities.

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

RAW = Path("../data/raw")
PROCESSED = Path("../data/processed")
FIGURES = Path("../figures")

rng = np.random.default_rng(42)
