# %% [markdown]
# # Problem exploration and dimension reduction
#
# Report section 1.3. Variables at play, their spread, and which ones move the answer.

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

RAW = Path("../data/raw")
PROCESSED = Path("../data/processed")
FIGURES = Path("../figures")

rng = np.random.default_rng(42)
