# %% [markdown]
# # Trade-off analysis
#
# Report section 3.2. Decision tree over the interventions, costs and benefits.

# %%
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

RAW = Path("../data/raw")
PROCESSED = Path("../data/processed")
FIGURES = Path("../figures")

rng = np.random.default_rng(42)
